# %% [markdown]
# ### Nama : Muhammad Romadon
# ### Kelas : SK4A
# ### Nim    : 09011182025015
# ### Mata Kuliah : Komunikasi Data

# %% [markdown]
# # Scraping Komentar Aplikasi Game Mobile Legend di Google Play Store

# %%
from google_play_scraper import app

import pandas as pd

import numpy as np

# %%
from google_play_scraper import Sort, reviews

result, continuation_token = reviews(
    'com.mobile.legends',
    lang='id', 
    country='id', 
    sort=Sort.MOST_RELEVANT, 
    count=5100, 
    filter_score_with=None 
)

# %%
df_busu = pd.DataFrame(np.array(result),columns=['review'])

df_busu = df_busu.join(pd.DataFrame(df_busu.pop('review').tolist()))

df_busu.head()
# Out:
#                                             reviewId  \
# 0  gp:AOqpTOFCEP-Dzb5-Ae3wr5Fc7iUxUfz6KaZuPff-euR...
# 1  gp:AOqpTOEkFu6ewobRTcL9atJv3kOPw11vsVUY0w2Vinz...
# 2  gp:AOqpTOFkrbBEdwcWoNlmOwbzu4efUac_NcC3XN_bpF9...
# 3  gp:AOqpTOGAvvkGqTcIMZYDLMdhd0ttCqPo2nj-YNq6342...
# 4  gp:AOqpTOEaiMbekfy_PTilw6ZmMCxqg6DL7xnPj0a3n3f...
#
#                    userName  \
# 0                 Uʟᴜʟ Aᴢᴍɪ
# 1                Al Muaemin
# 2            Akhmad Saubani
# 3                 Arya Bima
# 4  「Fikri」 Youtube:INDOSINI
#
#                                            userImage  \
# 0  https://play-lh.googleusercontent.com/a-/AOh14...
# 1  https://play-lh.googleusercontent.com/a-/AOh14...
# 2  https://play-lh.googleusercontent.com/a/AATXAJ...
# 3  https://play-lh.googleusercontent.com/a-/AOh14...
# 4  https://play-lh.googleusercontent.com/a-/AOh14...
#
#                                              content  score  thumbsUpCount  \
# 0  Secara keseluruhan semuanya udah bagus, mulai ...      5            649
# 1  Percuma di perbarui 1000%, kalo fitur masih it...      1            129
# 2  gamenya SERU banget🥳!!, hadiah hadiah dari eve...      5            179
# 3  Game nya udah bagus tapi saya punya saran kalo...      5              7
# 4  Sekarang sih udah lumayan update nya ditambah ...      5              6
#
#   reviewCreatedVersion                  at replyContent repliedAt
# 0             14.426.6 2022-04-28 02:19:39         None      None
# 1             14.426.6 2022-04-27 15:28:07         None      None
# 2             14.426.6 2022-04-26 21:05:28         None      None
# 3             14.426.6 2022-04-27 18:06:08         None      None
# 4             14.426.6 2022-04-27 19:25:08         None      None

# %%
new_df = df_busu[['userName', 'score','at', 'content']]
sorted_df = new_df.sort_values(by='at', ascending=False)
sorted_df.head()
# Out:
#            userName  score                  at  \
# 0         Uʟᴜʟ Aᴢᴍɪ      5 2022-04-28 02:19:39
# 5024  Deva Perdiana      5 2022-04-27 20:23:30
# 1388           obin      5 2022-04-27 20:22:17
# 4968   Jaka Prawira      5 2022-04-27 20:21:50
# 1301    hantu piano      1 2022-04-27 20:19:07
#
#                                                 content
# 0     Secara keseluruhan semuanya udah bagus, mulai ...
# 5024  game buruk,game tolol,game GK seru,membosankan...
# 1388  Saya suka game ini Komunitas clash of clans sa...
# 4968  Kk kenapa yang saya gak bisa masuk,, mental te...
# 1301  Bagus sekali gamenya sangat menghibur dan sang...

# %%
len(df_busu.index)
# Out:
# 5100

# %%
df_busu.head()
# Out:
#                                             reviewId  \
# 0  gp:AOqpTOFCEP-Dzb5-Ae3wr5Fc7iUxUfz6KaZuPff-euR...
# 1  gp:AOqpTOEkFu6ewobRTcL9atJv3kOPw11vsVUY0w2Vinz...
# 2  gp:AOqpTOFkrbBEdwcWoNlmOwbzu4efUac_NcC3XN_bpF9...
# 3  gp:AOqpTOGAvvkGqTcIMZYDLMdhd0ttCqPo2nj-YNq6342...
# 4  gp:AOqpTOEaiMbekfy_PTilw6ZmMCxqg6DL7xnPj0a3n3f...
#
#                    userName  \
# 0                 Uʟᴜʟ Aᴢᴍɪ
# 1                Al Muaemin
# 2            Akhmad Saubani
# 3                 Arya Bima
# 4  「Fikri」 Youtube:INDOSINI
#
#                                            userImage  \
# 0  https://play-lh.googleusercontent.com/a-/AOh14...
# 1  https://play-lh.googleusercontent.com/a-/AOh14...
# 2  https://play-lh.googleusercontent.com/a/AATXAJ...
# 3  https://play-lh.googleusercontent.com/a-/AOh14...
# 4  https://play-lh.googleusercontent.com/a-/AOh14...
#
#                                              content  score  thumbsUpCount  \
# 0  Secara keseluruhan semuanya udah bagus, mulai ...      5            649
# 1  Percuma di perbarui 1000%, kalo fitur masih it...      1            129
# 2  gamenya SERU banget🥳!!, hadiah hadiah dari eve...      5            179
# 3  Game nya udah bagus tapi saya punya saran kalo...      5              7
# 4  Sekarang sih udah lumayan update nya ditambah ...      5              6
#
#   reviewCreatedVersion                  at replyContent repliedAt
# 0             14.426.6 2022-04-28 02:19:39         None      None
# 1             14.426.6 2022-04-27 15:28:07         None      None
# 2             14.426.6 2022-04-26 21:05:28         None      None
# 3             14.426.6 2022-04-27 18:06:08         None      None
# 4             14.426.6 2022-04-27 19:25:08         None      None

# %%
df_busu.to_csv("scrapped_data Komentar Mobile Legend.csv", index = False)
